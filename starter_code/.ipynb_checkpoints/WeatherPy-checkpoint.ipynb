# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 583

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#sets the base url and parameters to retrieve city info from weather api
base_url="http://api.openweathermap.org/data/2.5/weather?"
params={"q":"Avarua", "appid":weather_api_key}

cities_raw_data=[]#stores all the data from the cities

#prints the header for the results
print()
print("Data Retrieval")
print("-------------------")

#loops through all of the cities, getting requests from weather api for each
for i, city in enumerate(cities):
    print(f"Processing Record {i}: {city}")
    try:
        params["q"]=city#updates the city for the search
        weather_response=requests.get(base_url, params=params).json()
        cities_raw_data.append(weather_response)#stores the city in the list
    except:
        print(f"Unable to process data for {city}.")
# Out:
# Data Retrieval
# -------------------
# Processing Record 0: busselton
# Processing Record 1: kapaa
# Processing Record 2: isangel
# Processing Record 3: soyo
# Processing Record 4: khani
# Processing Record 5: vostok
# Processing Record 6: provideniya
# Processing Record 7: cherskiy
# Processing Record 8: jamestown
# Processing Record 9: rikitea
# Processing Record 10: belushya guba
# Processing Record 11: jabinyanah
# Processing Record 12: klaksvik
# Processing Record 13: quatre cocos
# Processing Record 14: hereford
# Processing Record 15: aklavik
# Processing Record 16: matay
# Processing Record 17: albany
# Processing Record 18: torbay
# Processing Record 19: vaini
# Processing Record 20: bethel
# Processing Record 21: cape town
# Processing Record 22: avarua
# Processing Record 23: bredasdorp
# Processing Record 24: bluff
# Processing Record 25: chokurdakh
# Processing Record 26: butaritari
# Processing Record 27: ushuaia
# Processing Record 28: bumba
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#creates a dictionary to store only relevant information
cities_key_info={'City':[],
                'Lat':[],
                'Lng':[],
                'Max Temp':[],
                'Humidity':[],
                'Cloudiness':[],
                'Wind Speed':[],
                'Country':[],
                'Date':[]}

#loops through the raw data of the cities, storing information of interest in the dictionary
for j in range(len(cities_raw_data)-1):
    try:
        cities_key_info['City'].append(cities_raw_data[j]['name'])
        cities_key_info['Lat'].append(cities_raw_data[j]['coord']['lat'])
        cities_key_info['Lng'].append(cities_raw_data[j]['coord']['lon'])
        cities_key_info['Max Temp'].append(cities_raw_data[j]['main']['temp_max'])
        cities_key_info['Humidity'].append(cities_raw_data[j]['main']['humidity'])
        cities_key_info['Cloudiness'].append(cities_raw_data[j]['clouds']['all'])
        cities_key_info['Wind Speed'].append(cities_raw_data[j]['wind']['speed'])
        cities_key_info['Country'].append(cities_raw_data[j]['sys']['country'])
        cities_key_info['Date'].append(cities_raw_data[j]['dt'])
    except:
        pass #if city isn't found keep moving

cities_df=pd.DataFrame(cities_key_info)#creates a dataframe from the information
cities_df.to_csv("../output_data/cities_weathers.csv", index=False)#outputs to csv file
print(f'Number of cities with data: {len(cities_df)}')
cities_df.head()#prints sample response
# Out:
# Number of cities with data: 530
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Busselton -33.6500  115.3333    285.93        95           8        2.13
# 1      Kapaa  22.0752 -159.3190    296.15        78          75        5.14
# 2    Isangel -19.5500  169.2667    298.12        81         100        4.61
# 3       Soyo  -6.1349   12.3689    299.94        79          47        3.35
# 4      Khani  41.9563   42.9566    286.15        76          75        4.63
#
#   Country        Date
# 0      AU  1619370634
# 1      US  1619370650
# 2      VU  1619370667
# 3      AO  1619370672
# 4      GE  1619370673

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#reads the data from newly created csv to keep data consistent
csv_path="../output_data/cities_weathers.csv"
weather_csv_df=pd.read_csv(csv_path)

#converts weather column to fahrenheit
weather_csv_df["Max Temp"]=round((weather_csv_df["Max Temp"]-273.15)*(9/5)+32,1)

# %%
#looks for cities with 100% humidity and put them into new df
humid_cities_pd=weather_csv_df.loc[(weather_csv_df['Humidity'] > 100)]

#outputs the number of cities with over 100 % humidity
print(f"There are {len(humid_cities_pd)} city/cities with humidity over 100%")
# Out:
# There are 0 city/cities with humidity over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#There are no cities in my csv with over 100% humidity, so skipping the above step.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#reads the data from newly created csv to keep data consistent
csv_path="../output_data/cities_weathers.csv"
weather_csv_df=pd.read_csv(csv_path)

#converts weather column to fahrenheit 
weather_csv_df["Max Temp"]=round((weather_csv_df["Max Temp"]-273.15)*(9/5)+32,1)

#gets the values for the graph
lat_city=weather_csv_df['Lat']
temp_city=weather_csv_df['Max Temp']

#labels the graph
plt.title("City Latitude vs. Max Temperature (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.scatter(lat_city,temp_city,edgecolors="black")

#outputs the graph
plt.grid()
plt.savefig('../output_data/fig1_city_lat_vs_max_temp.png')
plt.show()

# %% [raw]
# Note: The above graph finds how the maximum temperature of a city is impacted by latitude. Temperture seems to increase as we reach a 0-20 latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#gets the values for the graph
humid_city=weather_csv_df['Humidity']

#labels the graph
plt.title("City Latitude vs. Humidity (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity  (%)")
plt.scatter(lat_city,humid_city,edgecolors="black")

#outputs the graph
plt.grid()
plt.savefig('../output_data/fig2_city_lat_vs_humidity.png')
plt.show()

# %% [raw]
# Note: The above graph finds how the overall humidity of a city is impacted by latitude. Visually there appears to be no strong correlation.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#gets the values for the graph
cloud_city=weather_csv_df['Cloudiness']

#labels the graph
plt.title("City Latitude vs. Cloudiness (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.scatter(lat_city,cloud_city,edgecolors="black")

#outputs the graph
plt.grid()
plt.savefig('../output_data/fig3_city_lat_vs_cloudiness.png')
plt.show()

# %% [raw]
# Note: The above graph finds how the overall cloudiness of a city is impacted by latitude. Visually, again, there appears to be no strong correlation.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#gets the values for the graph
wind_city=weather_csv_df['Wind Speed']

#labels the graph
plt.title("City Latitude vs. Wind Speed (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.scatter(lat_city,wind_city,edgecolors="black")

#outputs the graph
plt.grid()
plt.savefig('../output_data/fig4_city_lat_vs_wind_speed.png')
plt.show()

# %% [raw]
# Note: The above graph finds how the overall windspeed of a city is impacted by latitude. Visually, there seems to be maybe a slight correlation, with a greater variance of windspeed as we move further away from 0 latitude.

# %% [markdown]
# ## Linear Regression

# %%
#creates new dataframes splitting up cities into northern and southern latitudes
north_df=weather_csv_df.loc[weather_csv_df['Lat']>=0]
south_df=weather_csv_df.loc[weather_csv_df['Lat']<=0]

#finds north lat values
n_lat_city=north_df['Lat']
s_lat_city=south_df['Lat']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#find north temps
n_temp_city=north_df['Max Temp']

#labels the graph
plt.title("Northern City Latitude vs. Max Temperature (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.scatter(n_lat_city,n_temp_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat_city, n_temp_city)
regress_values = n_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(n_lat_city,regress_values,"r-")
plt.annotate(line_eq,(10,10),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig5_linear_N_city_lat_vs_max_temp.png')
plt.show()
# Out:
# The r-value is -0.8681518509389117

# %% [raw]
# There is a strong negative correlation between latitude and temperature as you go north of the equator. The variance is small.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#find south temps
s_temp_city=south_df['Max Temp']

#labels the graph
plt.title("Southern City Latitude vs. Max Temperature (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.scatter(s_lat_city,s_temp_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat_city, s_temp_city)
regress_values = s_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(s_lat_city,regress_values,"r-")
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig6_linear_S_city_lat_vs_max_temp.png')
plt.show()
# Out:
# The r-value is 0.7184030934140875

# %% [raw]
# There is a strong positive correlation between latitude and temperature as you near the equator from the south. The variance is small.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#find north humidity
n_humid_city=north_df['Humidity']

#labels the graph
plt.title("Northern City Latitude vs. Humidity (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(n_lat_city,n_humid_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat_city, n_humid_city)
regress_values = n_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(n_lat_city,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig7_linear_N_city_lat_vs_humidity.png')
plt.show()
# Out:
# The r-value is 0.2525849272643081

# %% [raw]
# There is a slight positive correlation between latitude and humidity as you go north of the equator. The variance is big, but narrows as you move north of the equator.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#find south humidity
s_humid_city=south_df['Humidity']

#labels the graph
plt.title("Southern City Latitude vs. Humidity (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(s_lat_city,s_humid_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat_city, s_humid_city)
regress_values = s_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(s_lat_city,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig8_linear_S_city_lat_vs_humidity.png')
plt.show()
# Out:
# The r-value is 0.14402600011699587

# %% [raw]
# There is minimal if any correlation between latitude and humidity as you near the equator from the south.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#find north clouds
n_cloud_city=north_df['Cloudiness']

#labels the graph
plt.title("Northern City Latitude vs. Cloudiness (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.scatter(n_lat_city,n_cloud_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat_city, n_cloud_city)
regress_values = n_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(n_lat_city,regress_values,"r-")
plt.annotate(line_eq,(45,50),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig9_linear_N_city_lat_vs_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.1412063185144017

# %% [raw]
# There is a very slight positive correlation between latitude and cloudiness as you go north of the equator. The variance is very wide, however.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#find south clouds
s_cloud_city=south_df['Cloudiness']

#labels the graph
plt.title("Southern City Latitude vs. Cloudiness (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.scatter(s_lat_city,s_cloud_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat_city, s_cloud_city)
regress_values = s_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(s_lat_city,regress_values,"r-")
plt.annotate(line_eq,(-55,24),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig10_linear_S_city_lat_vs_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.2476040200772106

# %% [raw]
# There is a very slight positive correlation between latitude and cloudiness as you head toward the equator from the south. The variance is very wide, however.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#find north windspeed
n_wind_city=north_df['Wind Speed']

#labels the graph
plt.title("Northern City Latitude vs. Wind Speed (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.scatter(n_lat_city,n_wind_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat_city, n_wind_city)
regress_values = n_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(n_lat_city,regress_values,"r-")
plt.annotate(line_eq,(0,12),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig11_linear_N_city_lat_vs_wind_speed.png')
plt.show()
# Out:
# The r-value is 0.0680120645944354

# %% [raw]
# There is a no correlation between latitude and windspeed as you go north of the equator.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#find south wind speed

s_wind_city=south_df['Wind Speed']

#labels the graph
plt.title("Southern City Latitude vs. Wind Speed (04/30/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.scatter(s_lat_city,s_wind_city,edgecolors="black")

#calculates the slope and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat_city, s_wind_city)
regress_values = s_lat_city * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plots the line
plt.plot(s_lat_city,regress_values,"r-")
plt.annotate(line_eq,(-55,8.5),fontsize=15,color="red")

#outputs the graph
print(f"The r-value is {rvalue}")
plt.savefig('../output_data/fig12_linear_N_city_lat_vs_wind_speed.png')
plt.show()
# Out:
# The r-value is -0.23866409579185066

# %% [raw]
# Final Observations:
#
# 1) Max temperature is strongly correlated to latitude, growing hotter closer to the equater
# 2) Cloudiness doesn't seem to correlate to latitude
# 3) Windiness diminishes as you near the equator (this surprises me and makes me think I may be wrong on this)
